# %%
from astrotools import reader

# %%
data = reader.read_osc('/Users/szymon/Dropbox/Projects/OSC/data/SN2011dh.json')
data_dict = reader.slice_band(data, band=['B', 'V'])

# %%
data_dict['B']
# Out:
#     band mag_err instrument     mag source system telescope         mjd  \
# 6      B   0.055       UVOT  15.355      3   Vega     Swift  55715.5799
# 12     B   0.055       UVOT  15.319      3   Vega     Swift  55716.2484
# 16     B   0.053       UVOT  15.072      3   Vega     Swift  55717.3188
# 23     B   0.048       UVOT  14.676      3   Vega     Swift  55718.5884
# 37     B   0.043       UVOT  14.143      3   Vega     Swift  55720.3331
# 40     B   0.043       UVOT  13.950      3   Vega     Swift  55721.3421
# 47     B   0.042       UVOT  13.745      3   Vega     Swift  55722.6797
# 56     B   0.042       UVOT  13.680      3   Vega     Swift  55723.4796
# 68     B   0.042       UVOT  13.596      3   Vega     Swift  55724.9611
# 79     B   0.042       UVOT  13.583      3   Vega     Swift  55726.2235
# 90     B   0.041       UVOT  13.489      3   Vega     Swift  55727.3584
# 102    B   0.041       UVOT  13.437      3   Vega     Swift  55728.8382
# ...
