# %%
from astrotools import reader

# %%
data = reader.read_osc('/Users/szymon/Dropbox/Projects/OSC/SN2011dh.json')
data_dict = reader.slice_band(data, band=['B', 'V'])

# %%
data_dict['B']
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>band</th>
#       <th>e_magnitude</th>
#       <th>instrument</th>
#       <th>magnitude</th>
#       <th>source</th>
#       <th>system</th>
#       <th>telescope</th>
#       <th>time</th>
#       <th>u_time</th>
#       <th>upperlimit</th>
#       <th>zp</th>
#       <th>flux</th>
#       <th>flux_err</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>B</td>
#       <td>0.055</td>
#       <td>UVOT</td>
#       <td>15.355</td>
#       <td>3</td>
#       <td>Vega</td>
#       <td>Swift</td>
#       <td>55715.5799</td>
#       <td>MJD</td>
#       <td>NaN</td>
#       <td>20.54</td>
#       <td>4.385307e-15</td>
#       <td>2.221459e-16</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>B</td>
#       <td>0.055</td>
#       <td>UVOT</td>
#       <td>15.319</td>
#       <td>3</td>
#       <td>Vega</td>
# ...
